# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB

# %%
data={
    'Cheap':['yes','yes','no','yes','no'],
    'Promo':['yes','no','yes','yes','no'],
    'Buy?':['yes','yes','no','yes','no']
}

# %%
df=pd.DataFrame(data)

# %%
le_cheap=LabelEncoder()
le_promo=LabelEncoder()
le_buy=LabelEncoder()

# %%
df['Cheap']=le_cheap.fit_transform(df['Cheap']) 
df['Promo']=le_promo.fit_transform(df['Promo'])
df['Buy?']=le_buy.fit_transform(df['Buy?'])

# %%
X=df[['Cheap','Promo']]
y=df['Buy?']

# %%
model=CategoricalNB()
model.fit(X,y)
# Out:
# CategoricalNB()

# %%
y_pred=model.predict(X)

# %%
df['Predicted_Buy']=le_buy.inverse_transform(y_pred)
df['Actual_Buy']=le_buy.inverse_transform(y)

# %%
print(df)
# Out:
#    Cheap  Promo  Buy? Predicted_Buy Actual_Buy
# 0      1      1     1           yes        yes
# 1      1      0     1           yes        yes
# 2      0      1     0            no         no
# 3      1      1     1           yes        yes
# 4      0      0     0            no         no

# %%
print(df['Promo'])
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Promo, dtype: int32

# %%
print(data['Promo'])
# Out:
# ['yes', 'no', 'yes', 'yes', 'no']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.plot(y_test, label="Actual", marker='o')
plt.plot(y_pred, label="Predicted", marker='x')
plt.title("Actual vs Predicted Comparison")
plt.xlabel("Sample Index")
plt.ylabel("Class")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(8,4))
# ----> 4 plt.plot(y_test, label="Actual", marker='o')
#       5 plt.plot(y_pred, label="Predicted", marker='x')
#       6 plt.title("Actual vs Predicted Comparison")
#
# NameError: name 'y_test' is not defined
